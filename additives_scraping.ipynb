# %%
import pandas as pd
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager # sustituye al archivo
from selenium import webdriver
import time
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By # By es para buscar por tag, clase, id...
from fake_useragent import UserAgent
from selenium.webdriver.support.ui import WebDriverWait   # es para esperar
from selenium.webdriver.support import expected_conditions as EC  # condiciones esperadas...
from selenium.webdriver import ActionChains as AC   # acciones encadenadas, rollo doble click
from selenium.webdriver.common.keys import Keys  # manejar teclas

# %%
# Install and configure the Chrome web driver
PATH = ChromeDriverManager().install()

# Initialize the Chrome web driver
driver = webdriver.Chrome(PATH)
"""
url = 'https://www.marca.com/'
# Now you can use the 'driver' object for web scraping
driver.get(url)"""
# Out:
# "\nurl = 'https://www.marca.com/'\n# Now you can use the 'driver' object for web scraping\ndriver.get(url)"

# %%
opciones=Options()


opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

opciones.headless=True   # si True, no aparece la ventana (headless=no visible)

opciones.add_argument('user-data-dir=cookies')    # mantiene las coockies


opciones.add_argument('--incognito')              # incognito


from fake_useragent import UserAgent

usuario=UserAgent().random



print(usuario)
# Out:
# Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36

# %%
"""list1 = []

for page_num in range(2, 300):
    

    parent_div = driver.find_element_by_css_selector('ul#products_match_all')

    # Find all the <a> elements inside the parent <div>
    links = parent_div.find_elements_by_tag_name('a')

    # Extract the href attribute from each link
    for link in links:
        href = link.get_attribute('href')
        list1.append(href)
        
    button = driver.find_element_by_css_selector(f'a[href="/{page_num}?sort_by=popularity"]')

    # Click the button
    button.click()"""
# Out:
# 'list1 = []\n\nfor page_num in range(2, 300):\n    \n\n    parent_div = driver.find_element_by_css_selector(\'ul#products_match_all\')\n\n    # Find all the <a> elements inside the parent <div>\n    links = parent_div.find_elements_by_tag_name(\'a\')\n\n    # Extract the href attribute from each link\n    for link in links:\n        href = link.get_attribute(\'href\')\n        list1.append(href)\n        \n    button = driver.find_element_by_css_selector(f\'a[href="/{page_num}?sort_by=popularity"]\')\n\n    # Click the button\n    button.click()'

# %%
"""from selenium.common.exceptions import NoSuchElementException

data_list = []

for e in list1:
    # Open the webpage

       
        
        driver.get(e)  # Replace with the actual webpage URL

       
        try:
            # Find the <h2> element with the specific class name
            h2_element = driver.find_element_by_class('h2.title-1')

            # Extract the text content of the <h2> element
            product_name = h2_element.text
        
        except NoSuchElementException:
            product_name = 'unknown'
        
        
        try:
            # Find the <span> element with the specific id for brands
            span_brands = driver.find_element_by_id('field_brands_value')

            # Find the <a> elements within the <span> element for brands
            a_elements_brands = span_brands.find_elements_by_tag_name('a')

            # Extract the text content of each <a> element for brands
            brands = [a_brand.text for a_brand in a_elements_brands]
        
        except NoSuchElementException:
            brands = 'unknown'

        # Find the <span> element with the specific id for packaging
        # span_packaging = driver.find_element_by_id('field_packaging_value')

        # Find the <a> elements within the <span> element for packaging
        # a_elements_packaging = span_packaging.find_elements_by_tag_name('a')

        # Extract the text content of each <a> element for packaging
        # packaging = [a_packaging.text for a_packaging in a_elements_packaging]

        
        try:
            
            # Find the <a> element within the <a> element with href="#panel_nutriscore_content"
            nutri_a_element = driver.find_element_by_css_selector('a[href="#panel_nutriscore_content"]')

            # Extract the "grade" class attribute of the <a> element for Nutri-Score
            nutri_score = nutri_a_element.get_attribute("class").split()[1].replace("grade_", "").upper()
        
        except NoSuchElementException:
            nutri_score = 'unknown'
       
    
    
        try:
            # Find the <a> element within the <a> element with href="#panel_nova_content"
            nova_a_element = driver.find_element_by_css_selector('a[href="#panel_nova_content"]')

            # Extract the text content of the <h4> element within the <a> element for NOVA 4
            nova_4 = nova_a_element.find_element_by_tag_name('h4').text
        
        except NoSuchElementException:
            nova_4 = 'unknown'

            
            
        try:
            
            # Find the <span> element with the specific id for countries
            span_countries = driver.find_element_by_id('field_countries_value')

            # Find the <a> elements within the <span> element for countries
            a_elements_countries = span_countries.find_elements_by_tag_name('a')

            # Extract the text content of each <a> element for countries
            countries = [a_country.text for a_country in a_elements_countries]
        
        except NoSuchElementException:
            countries = 'unknown'

            
            
        try:
            #Find the <div> element with the specific id for additives content
            div_additives_content = driver.find_element_by_id('panel_additives_content')

            #Find all the <h4> elements within the <div> element for additives content
            h4_elements_additives = div_additives_content.find_elements_by_tag_name('h4')

            #Extract the additive information from the <h4> elements
            additives = [h4_additive.text for h4_additive in h4_elements_additives]
            
        except NoSuchElementException:
            additives = 'unknown'

        
        try:
            # Find the <a> element with the specific id for Eco-Score
            a_ecoscore = driver.find_element_by_css_selector('a[href="#panel_ecoscore"]')

            # Extract the Eco-Score information from the <a> element
            eco_score = a_ecoscore.find_element_by_css_selector('h4.attr_title').text
        
        except NoSuchElementException:
            eco_score = 'unknown'

        # Create a table
        current_data = {
            'Product Name': product_name,
            'Brands': ', '.join(brands),
            #'Packaging': ', '.join(packaging),
            'NOVA 4': nova_4,
            'Nutri-Score': nutri_score,
            'Countries': ', '.join(countries),
            'Additives': ', '.join(additives),
            'Eco-Score': eco_score

        }

        from bs4 import BeautifulSoup
        
        try:
            # Extract the page source
            page_source = driver.page_source

            # Parse the HTML data
            soup = BeautifulSoup(page_source, 'html.parser')

            # Find the <tbody> element within the table
            tbody_element = soup.find('table', attrs={'aria-label': 'Información nutricional'}).find('tbody')

            # Create a dictionary to store the extracted values
            extracted_data = {}

            # Find the rows with the desired keys
            for row in tbody_element.find_all('tr'):
                key_element = row.find('td').find('span')
                key = key_element.text.strip()

                # Check if the current row contains 'Energía', 'Grasas saturadas', or 'Azúcares'
                if key == 'Energía' or key == 'Grasas saturadas' or key == 'Azúcares':
                    value_element = row.find_all('td')[1].find('span')
                    value = value_element.text.strip()
                    extracted_data[key] = value

            # Add the extracted values to the existing data dictionary
            current_data['Energía'] = extracted_data['Energía']
            current_data['Grasas saturadas'] = extracted_data['Grasas saturadas']
            current_data['Azúcares'] = extracted_data['Azúcares']
        
        
        except Exception as e:
        # Handle the exception
            pass
        
        data_list.append(current_data)"""
# Out:
# 'from selenium.common.exceptions import NoSuchElementException\n\ndata_list = []\n\nfor e in list1:\n    # Open the webpage\n\n       \n        \n        driver.get(e)  # Replace with the actual webpage URL\n\n       \n        try:\n            # Find the <h2> element with the specific class name\n            h2_element = driver.find_element_by_class(\'h2.title-1\')\n\n            # Extract the text content of the <h2> element\n            product_name = h2_element.text\n        \n        except NoSuchElementException:\n            product_name = \'unknown\'\n        \n        \n        try:\n            # Find the <span> element with the specific id for brands\n            span_brands = driver.find_element_by_id(\'field_brands_value\')\n\n            # Find the <a> elements within the <span> element for brands\n            a_elements_brands = span_brands.find_elements_by_tag_name(\'a\')\n\n            # Extract the text content of each <a> element for brands\n            brands = [a_brand.text for a_brand in a_elements_brands]\n        \n        except NoSuchElementException:\n            brands = \'unknown\'\n\n        # Find the <span> element with the specific id for packaging\n        # span_packaging = driver.find_element_by_id(\'field_packaging_value\')\n\n        # Find the <a> elements within the <span> element for packaging\n        # a_elements_packaging = span_packaging.find_elements_by_tag_name(\'a\')\n\n        # Extract the text content of each <a> element for packaging\n        # packaging = [a_packaging.text for a_packaging in a_elements_packaging]\n\n        \n        try:\n            \n            # Find the <a> element within the <a> element with href="#panel_nutriscore_content"\n            nutri_a_element = driver.find_element_by_css_selector(\'a[href="#panel_nutriscore_content"]\')\n\n            # Extract the "grade" class attribute of the <a> element for Nutri-Score\n            nutri_score = nutri_a_element.get_attribute("class").split()[1].replace("grade_", "").upper()\n        \n        except NoSuchElementException:\n            nutri_score = \'unknown\'\n       \n    \n    \n        try:\n            # Find the <a> element within the <a> element with href="#panel_nova_content"\n            nova_a_element = driver.find_element_by_css_selector(\'a[href="#panel_nova_content"]\')\n\n            # Extract the text content of the <h4> element within the <a> element for NOVA 4\n            nova_4 = nova_a_element.find_element_by_tag_name(\'h4\').text\n        \n        except NoSuchElementException:\n            nova_4 = \'unknown\'\n\n            \n            \n        try:\n            \n            # Find the <span> element with the specific id for countries\n            span_countries = driver.find_element_by_id(\'field_countries_value\')\n\n            # Find the <a> elements within the <span> element for countries\n            a_elements_countries = span_countries.find_elements_by_tag_name(\'a\')\n\n            # Extract the text content of each <a> element for countries\n            countries = [a_country.text for a_country in a_elements_countries]\n        \n        except NoSuchElementException:\n            countries = \'unknown\'\n\n            \n            \n        try:\n            #Find the <div> element with the specific id for additives content\n            div_additives_content = driver.find_element_by_id(\'panel_additives_content\')\n\n            #Find all the <h4> elements within the <div> element for additives content\n            h4_elements_additives = div_additives_content.find_elements_by_tag_name(\'h4\')\n\n            #Extract the additive information from the <h4> elements\n            additives = [h4_additive.text for h4_additive in h4_elements_additives]\n            \n        except NoSuchElementException:\n            additives = \'unknown\'\n\n        \n        try:\n            # Find the <a> element with the specific id for Eco-Score\n            a_ecoscore = driver ...

# %%
driver.get("https://www.aditivos-alimentarios.com/") 

time.sleep(3)

# %%
rows = driver.find_elements(By.CLASS_NAME, "notranslate")

# %%
list1=[]

for row in rows:
    a=row.text
    list1.append(a)

list1
# Out:
# ["E100 Curcuminas BAJA\nE100i Curcumina BAJA\nE100ii Cúrcuma BAJA\nE101 Riboflavinas BAJA\nE101i Riboflavina BAJA\nE101ii Fosfato de Riboflavina BAJA\nE101iii Riboflavina de Bacillus Subtilis BAJA\nE101iv Riboflavina de Ashbya Gossypii BAJA\nE102 Tartracina ALTA\nE103 Crisoína ALTA\nE104 Amarillo de Quinoleína MEDIA\nE105 Amarillo Sólido ALTA\nE107 Amarillo 2G ALTA\nE110 Amarill
En revisión\nE163v Colorante de Col Lombarda En revisión\nE163vi Extracto de Zanahoria Negra En revisión\nE163vii Colorante de Batata Morada En revisión\nE163viii Colorante de Rábano Rojo En revisión\nE163ix Colorante de Saúco En revisión\nE163x Colorante de Hibisco En revisión\nE163xi Extracto de Campanilla Azul En revisión\nE163a Cianidina BAJA\nE163b Delfinidina BAJA\nE163c Malvidina BAJA\nE163d Pelargonidina BAJA\nE163e Peonidina BAJA\nE163f Petunidina BAJA\nE164 Amarillo de Gardenia En revisión\nE165 Azul de Gardenia ALTA\nE166 Madera de Sándalo En revisión\nE170 Carbonatos Cálcicos BAJA\nE170i Carbonato Cálcico BAJA\nE170ii Bicarbonato Cálcico BAJA\nE171 Dióxido de Titanio ALTA\nE172 Óxidos e Hidróxidos Férricos BAJA\nE172i Óxido Férrico Negro En revisión\nE172ii Óxido Férrico Rojo En revisión\nE172iii Óxido Férrico Amarillo En revisión\nE173 Aluminio Comestible ALTA\nE174 Plata Comestible ALTA\nE175 Oro Comestible ALTA\nE176 Pigmentos Nacarados de Aluminosilicato Potásico  ...

# %%
list_series=pd.Series(list1)
list_series=list_series.str.split("\n")

# %%
list_series
# Out:
# 0    [E100 Curcuminas BAJA, E100i Curcumina BAJA, E...
# dtype: object

# %%
df = pd.DataFrame(list_series.explode())

# %%
df.info()

time.sleep(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 751 entries, 0 to 0
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       751 non-null    object
# dtypes: object(1)
# memory usage: 11.7+ KB

# %%
df.rename(columns={0: 'new_name'}, inplace=True)
df
# Out:
#                                     new_name
# 0                       E100 Curcuminas BAJA
# 0                       E100i Curcumina BAJA
# 0                        E100ii Cúrcuma BAJA
# 0                     E101 Riboflavinas BAJA
# 0                     E101i Riboflavina BAJA
# ..                                       ...
# 0         E1518 Triacetato de Glicerilo BAJA
# 0              E1519 Alcohol Bencílico MEDIA
# 0                  E1520 Propilenglicol BAJA
# 0                E1521 Polietilenglicol ALTA
# 0   E1522 Lignosulfonato Cálcico En revisión
#
# [751 rows x 1 columns]

# %%
df.reset_index(drop=True, inplace=True)

df
# Out:
#                                      new_name
# 0                        E100 Curcuminas BAJA
# 1                        E100i Curcumina BAJA
# 2                         E100ii Cúrcuma BAJA
# 3                      E101 Riboflavinas BAJA
# 4                      E101i Riboflavina BAJA
# ..                                        ...
# 746        E1518 Triacetato de Glicerilo BAJA
# 747             E1519 Alcohol Bencílico MEDIA
# 748                 E1520 Propilenglicol BAJA
# 749               E1521 Polietilenglicol ALTA
# 750  E1522 Lignosulfonato Cálcico En revisión
#
# [751 rows x 1 columns]

# %%
# df[['additive', 'type', 'toxicity']] = df[0].str.split(expand=True)

# df[['additive', 'type', 'toxicity']] = pd.DataFrame(df['new_name'].str.split().tolist(), columns=['additive', 'type', 'toxicity'])

df[['additive', 'type', 'toxicity']] = df['new_name'].str.rsplit(' ', n=2, expand=True)

# df[['additive', 'type', 'toxicity']] = df['new_name'].str.extract(r'^(?P<additive>E\d+)(?P<type>.+?)\s(?P<toxicity>BAJA|\w+\s*\w+)?$')

pd.set_option('display.max_rows', None)

df
# Out:
#                                               new_name  \
# 35             E141 Complejos Cúpricos de Clorofilas y
# 36                           E141i Complejo Cúprico de
# 37                          E141ii Complejo Cúprico de
# 38                                          E142 Verde
# 39                                   E143 Verde Sólido
# 40                                                E150
# 41                                      E150a Caramelo
# 42                          E150b Caramelo Caústico de
# 43                                      E150c Caramelo
# 44                           E150d Caramelo Amónico de
# 45                                E151 Negro Brillante
# 46                                          E152 Negro
# 47                                         E153 Carbón
# 48                                         E154 Marrón
# 49                                         E155 Marrón
# 50                                                E160
# 51                                               E160a
# 52                     E160a(i) Betacaroteno Sintético
# 53                      E160a(ii) Betacaroteno Vegetal
# 54       E160a(iii) Betacaroteno de Blakeslea Trispora
# 55                     E160a(iv) Betacaroteno de Algas
# 56                                  E160b Extractos de
# 57         E160b(i) Extracto de Annato con Disolventes
# 58            E160b(ii) Extracto de Annato con Álcalis
# 59            E160b(iii) Extracto de Annato con Aceite
# 60                                  E160c Extractos de
# 61                    E160c(i) Oleorresina de Pimentón
# 62                      E160c(ii) Extracto de Pimentón
# 63                                               E160d
# 64                         E160d(i) Licopeno Sintético
# 65                        E160d(ii) Licopeno de Tomate
# 66           E160d(iii) Licopeno de Blakeslea Trispora
# 67                         E160e Beta-Apo-8'-Carotenal
# 68                       E160f Éster Etílico del Ácido
# 69                                                E161
# 70                                               E161a
# 71                                               E161b
# 72                  E161b(i) Luteína de Tagetes Erecta
# 73                       E161b(ii) Extracto de Tagetes
# ...
# 396                     Potásico     MEDIA
# 397               Sódico-Cálcico     MEDIA
# 398                      Cálcico     MEDIA
# 399                      Amónico     MEDIA
# 400                           En  revisión
# 401                           En  revisión
# 402                           En  revisión
# 403                           En  revisión
# 404                           En  revisión
# 405                           En  revisión
# 406                           En  revisión
# 407                           En  revisión
# 408                    Celulosas     MEDIA
# 409              Microcristalina     MEDIA
# 410                        Polvo     MEDIA
# 411               Metil-Celulosa     MEDIA
# 412                Etil-Celulosa     MEDIA
# 413       Hidroxipropil-Celulosa     MEDIA
# 414  Hidroxipropilmetil-Celulosa     MEDIA
# 415           Metiletil-Celulosa     MEDIA
# 416                       Sódica     MEDIA
# 417     Etilhidroxietil-Celulosa     MEDIA
# 418                  Entrelazada     MEDIA
# 419              Enzimáticamente     MEDIA
# 420                       Grasos      BAJA
# 421                           En  revisión
# 422                           En  revisión
# 423                           En  revisión
# 424                       Calcio      BAJA
# 425                     Magnesio      BAJA
# 426                       Grasos     MEDIA
# 427                       Grasos     MEDIA
# 428                       Grasos     MEDIA
# 429                       Grasos     MEDIA
# 430                       Grasos     MEDIA
# 431                       Grasos     MEDIA
# 432                       Grasos     MEDIA
# 433                       Grasos     MEDIA
# 434                           En  revisión
# 435                       Grasos     MEDIA
# 436                           En  revisión
# 437                       Grasos     MEDIA
# 438                       Grasos     MEDIA
# 439                 Poliglicerol      BAJA
# 440                       Grasos     MEDIA
# 441                           En  revisión
# 442                     Oxidados     MEDIA
# 443                           En  revisión
# 444                           En  revisión
# 445                       Sódico     MEDIA
# 446                      Sódicos      BAJA
# 447                       Sódico      BAJA
# 448                           En  revisión
# 449                     Cálcicos      BAJA
# 450                           En  revisión
# 451                           En  revisión
# 452                  Estearílico      BAJA
# 453                           En  revisión
# 454                           En  revisión
# 455                           En  revisión
# 456                           En  revisión
# 457                           En  revisión
# 458                           En  revisión
# 459                    Sorbitano      ALTA
# 460                    Sorbitano      ALTA
# 461                    Sorbitano      ALTA
# 462                    Sorbitano      ALTA
# 463                    Sorbitano      ALTA
# 464                    Sorbitano      ALTA
# 465                Estigmasterol      BAJA
# 466                      Sódicos      BAJA
# 467                       Sódico      BAJA
# 468                       Sódico      BAJA
# 469                           En  revisión
# 470                    Potásicos      BAJA
# 471                     Potásico      BAJA
# 472                     Potásico      BAJA
# 473                     Amónicos      BAJA
# 474                      Amónico      BAJA
# 475                      Amónico      BAJA
# 476                   Magnésicos      BAJA
# 477                    Magnésico      BAJA
# 478                    Magnésico      BAJA
# 479                           En  revisión
# 480                  Clorhídrico      ALTA
# 481                     Potásico      ALTA
# 482                      Cálcico      ALTA
# 483                      Amónico      ALTA
# 484                    Magnésico      BAJA
# 485                     Estañoso      ALTA
# 486                    Sulfúrico      ALTA
# 487                      Sódicos     MEDIA
# 488                       Sódico     MEDIA
# 489                       Sódico     MEDIA
# 490                    Potásicos     MEDIA
# 491                     Potásico     MEDIA
# 492                     Potásico     MEDIA
# 493                     Cálcicos     MEDIA
# 494                      Cálcico     MEDIA
# 495                      Cálcico     MEDIA
# 496                     Amónicos     MEDIA
# 497                      Amónico     MEDIA
# 498                      Amónico     MEDIA
# 499                   Magnésicos     MEDIA
# 500                    Magnésico     MEDIA
# 501                    Magnésico     MEDIA
# 502                     Cúpricos      ALTA
# 503                      Cúprico      ALTA
# 504                      Cúprico      ALTA
# 505                    Alumínico      ALTA
# 506             Alumínico-Sódico      ALTA
# 507           Alumínico-Potásico      ALTA
# 508            Alumínico-Amónico      ALTA
# 509                       Sódico     MEDIA
# 510                     Potásico     MEDIA
# 511                      Cálcico     MEDIA
# 512                      Amónico      ALTA
# 513                    Magnésico     MEDIA
# 514                      Cálcico     MEDIA
# 515                    Magnésico     MEDIA
# 516                           En  revisión
# 517                       Sódico     MEDIA
# 518                     Potásico     MEDIA
# 519                           En  revisión
# 520                      Cálcico     MEDIA
# 521                           En  revisión
# 522                      Cálcico     MEDIA
# 523           Alumínicos-Sódicos      ALTA
# 524             Alumínico-Sódico      ALTA
# 525             Alumínico-Sódico      ALTA
# 526                      Cálcico      ALTA
# 527             Sódicos-Cálcicos     MEDIA
# 528                     Cálcicos     MEDIA
# 529                     Amónicos     MEDIA
# 530                   Magnésicos     MEDIA
# 531                           En  revisión
# 532                           En  revisión
# 533                           En  revisión
# 534                      Silicio      ALTA
# 535                      Cálcico      ALTA
# 536                   Magnésicos      ALTA
# 537                    Magnésico      ALTA
# 538                           En  revisión
# 539                           En  revisión
# 540                    Magnésico      ALTA
# 541             Sódico-Alumínico      ALTA
# 542           Potásico-Alumínico      ALTA
# 543            Cálcico-Alumínico      ALTA
# 544                           En  revisión
# 545                    Bentonita      BAJA
# 546                    Alumínico      ALTA
# 547                           En  revisión
# 548                    Esteárico     MEDIA
# 549                    Glucónico      BAJA
# 550        Glucono-Delta-Lactona      BAJA
# 551                       Sódico      BAJA
# 552                     Potásico      BAJA
# 553                      Cálcico      BAJA
# 554                      Ferroso      BAJA
# 555                      Ferroso      BAJA
# 556                           En  revisión
# 557                    Glutámico      ALTA
# 558                   Monosódico      ALTA
# 559                 Monopotásico      ALTA
# 560                      Cálcico      ALTA
# 561                  Monoamónico      ALTA
# 562                    Magnésico      ALTA
# 563                    Guanílico      ALTA
# 564                       Sódico      ALTA
# 565                     Potásico      ALTA
# 566                      Cálcico      ALTA
# 567                    Inosínico      ALTA
# 568                       Sódico      ALTA
# 569                     Potásico      ALTA
# 570                      Cálcico      ALTA
# 571                      Cálcico      ALTA
# 572                       Sódico      ALTA
# 573                       Maltol     MEDIA
# 574                   Etilmaltol     MEDIA
# 575                           En  revisión
# 576                           En  revisión
# 577                      Sódicas      ALTA
# 578                           En  revisión
# 579                           En  revisión
# 580                      Leucina     MEDIA
# 581                           En  revisión
# 582                      Zíncico     MEDIA
# 583                          DMS      ALTA
# 584                         PDMS      ALTA
# 585                         PMFS      ALTA
# 586                       Abejas      BAJA
# 587                       Blanca      BAJA
# 588                     Amarilla      BAJA
# 589                   Candelilla      BAJA
# 590                     Carnaúba      BAJA
# 591                         Laca     MEDIA
# 592                           En  revisión
# 593                           En  revisión
# 594              Microcristalina      ALTA
# 595                           En  revisión
# 596                           En  revisión
# 597                           En  revisión
# 598                           En  revisión
# 599                           En  revisión
# 600                           En  revisión
# 601                           En  revisión
# 602                           En  revisión
# 603                  Hidrogenado      ALTA
# 604                           En  revisión
# 605                           En  revisión
# 606                           En  revisión
# 607                           En  revisión
# 608                    Montánico     MEDIA
# 609                   (Lanolina)      BAJA
# 610                      Oxidada      ALTA
# 611                           En  revisión
# 612                           En  revisión
# 613                           En  revisión
# 614                           En  revisión
# 615                           En  revisión
# 616                     Cisteína      BAJA
# 617                      Cistina      BAJA
# 618                           En  revisión
# 619                           En  revisión
# 620                           En  revisión
# 621                           En  revisión
# 622                           En  revisión
# 623                           En  revisión
# 624                           En  revisión
# 625                           En  revisión
# 626             Azodicarbonamida      ALTA
# 627                       (Urea)      BAJA
# 628                           En  revisión
# 629                           En  revisión
# 630                           En  revisión
# 631                        Argón      BAJA
# 632                        Helio      BAJA
# 633                           En  revisión
# 634                    Nitrógeno      BAJA
# 635                      Nitroso      BAJA
# 636                      Butanos      ALTA
# 637                       Butano      ALTA
# 638                    Isobutano      ALTA
# 639                      Propano      ALTA
# 640                           En  revisión
# 641                           En  revisión
# 642                      Oxígeno      BAJA
# 643                    Hidrógeno      BAJA
# 644                            K      ALTA
# 645                    Aspartamo      ALTA
# 646                     Cálcicas      ALTA
# 647                    Ciclámico      ALTA
# 648                       Sódico      ALTA
# 649                      Cálcico      ALTA
# 650                   Isomaltosa      BAJA
# 651                    Potásicas      ALTA
# 652                     Sacarina      ALTA
# 653                       Sódica      ALTA
# 654                      Cálcica      ALTA
# 655                     Potásica      ALTA
# 656                    Sucralosa      ALTA
# 657                           En  revisión
# 658                    Taumatina      BAJA
# 659                 Glicirricina      ALTA
# 660                       (NHDC)     MEDIA
# 661                     Esteviol     MEDIA
# 662                           En  revisión
# 663                           En  revisión
# 664                           En  revisión
# 665                           En  revisión
# 666                           En  revisión
# 667                      Neotamo      ALTA
# 668                   Acesulfamo      ALTA
# 669                     Tagatosa      BAJA
# 670                           En  revisión
# 671                   Maltitoles     MEDIA
# 672                     Maltitol     MEDIA
# 673                     Maltitol     MEDIA
# 674                     Lactitol     MEDIA
# 675                      Xilitol      BAJA
# 676                    Eritritol      ALTA
# 677                    Advantame     MEDIA
# 678                      Quilaya     MEDIA
# 679                           En  revisión
# 680                           En  revisión
# 681                           En  revisión
# 682                           En  revisión
# 683                           En  revisión
# 684                           En  revisión
# 685                           En  revisión
# 686                           En  revisión
# 687                           En  revisión
# 688                           En  revisión
# 689                     Amilasas     MEDIA
# 690                           En  revisión
# 691                           En  revisión
# 692                           En  revisión
# 693                           En  revisión
# 694                           En  revisión
# 695                           En  revisión
# 696                           En  revisión
# 697                           En  revisión
# 698                           En  revisión
# 699                           En  revisión
# 700                           En  revisión
# 701                           En  revisión
# 702                           En  revisión
# 703                           En  revisión
# 704                   Invertasas      BAJA
# 705                           En  revisión
# 706                     Lisozima     MEDIA
# 707                Polidextrosas      BAJA
# 708                        (PVP)      ALTA
# 709                       (PVPP)      ALTA
# 710                 Polivinílico     MEDIA
# 711                     Pululano      BAJA
# 712                           En  revisión
# 713                           En  revisión
# 714                           En  revisión
# 715                       Vinilo      ALTA
# 716                        (PVE)     MEDIA
# 717                           En  revisión
# 718                    Dextrinas     MEDIA
# 719                        Ácido     MEDIA
# 720                     Alcalino     MEDIA
# 721                   Blanqueado     MEDIA
# 722                      Oxidado     MEDIA
# 723                   Enzimático     MEDIA
# 724                  Monoalmidón     MEDIA
# 725                    Dialmidón     MEDIA
# 726                    Fosfatado     MEDIA
# 727                    Acetilado     MEDIA
# 728                    Acetilado     MEDIA
# 729                    Acetilado     MEDIA
# 730        Hidroxipropil-Almidón     MEDIA
# 731             Hidroxipropilado     MEDIA
# 732             Hidroxipropilado     MEDIA
# 733                      Almidón     MEDIA
# 734                    Acetilado     MEDIA
# 735                      Almidón     MEDIA
# 736                           En  revisión
# 737                           En  revisión
# 738                       Ricino     MEDIA
# 739                           En  revisión
# 740                           En  revisión
# 741                           En  revisión
# 742                   Trietílico     MEDIA
# 743                           En  revisión
# 744                    Glicerilo      BAJA
# 745                    Glicerilo      BAJA
# 746                    Glicerilo      BAJA
# 747                    Bencílico     MEDIA
# 748               Propilenglicol      BAJA
# 749             Polietilenglicol      ALTA
# 750                           En  revisión

# %%
df

# %%
level1=df[0].str.split(' ')
level1[0]

# %%
level2 = pd.DataFrame(level1)
level2 = level2.rename(columns={0: 'col'})
level2.info()

# %%
level2.head()

# %%
level2.dtypes

# %%
level2['col']=level2['col'].astype(str)
level2.dtypes

# %%
level2['col'] = level2['col'].str.strip("[]")

level2[['additive', 'type', 'toxicity']] = level2.str.split(expand=True)

# %%
#df.to_csv("/Users/david/Desktop/IronHack/Projects/food_advisor/raw/food_additives.csv")
